# %% [markdown]
# <a href="https://colab.research.google.com/github/Open-Finance-Lab/FinRL_Contest_2024/blob/main/Tutorials/FinRL_stock_trading_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1. Install Packages

# %%
## install required packages
# !pip install swig
# !pip install box2d
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.5 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1
# Collecting box2d
#   Downloading Box2D-2.3.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py) ... done
#   Created wheel for box2d: filename=Box2D-2.3.2-cp310-cp310-linux_x86_64.whl size=2391308 sha256=4f729e09a4b0afbd51723677dd576713beeb53a4c4555144c0b5d9420645d7ab
#   Stored in directory: /root/.cache/pip/wheels/eb/cb/be/e663f3ce9aba6580611c0febaf7cd3cf7603f87047de2a52f9
# Successfully built box2d
# Installing collected packages: box2d
# Successfully installed box2d-2.3.2
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-cb8l61md
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-cb8l61md
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 7c71056dd6d72e205096696319a2d8bd4a2bfe23
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-yoe7s4ai/elegantrl_e415897e97f74e57a832c08c0c38e7dc
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-yoe7s4ai/elegantrl_e415897e97f74e57a832c08c0c38e7dc
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit a68515548417093006eb7f68738b55a3a758645e
#   Preparing metadata (setup.py) ... done
# Collecting alpaca-trade-api<4,>=3 (from finrl==0.3.6)
#   Downloading alpaca_trade_api-3.0.2-py3-none-any.whl (34 kB)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Downloading ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 13.2 MB/s eta 0:00:00
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Downloading exchange_calendars-4.5-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.0/191.0 kB 21.1 MB/s eta 0:00:00
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Downloading jqdatasdk-1.9.1-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 16.8 MB/s eta 0:00:00
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.6)
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 7.9 MB/s eta 0:00:00
# Collecting ray[default,tune]<3,>=2 (from finrl==0.3.6)
#   Downloading ray-2.7.1-cp310-cp310-manylinux2014_x86_64.whl (62.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 MB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.2.2)
# Collecting stable-baselines3[extra]>=2.0.0a5 (from finrl==0.3.6)
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 17.2 MB/s eta 0:00:00
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Downloading stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Collecting wrds<4,>=3 (from finrl==0.3.6)
#   Downloading wrds-3.1.6-py3-none-any.whl (12 kB)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.2.31)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.3)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.23.5)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.6.4)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.3 MB/s eta 0:00:00
# Collecting msgpack==1.0.3 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 34.3 MB/s eta 0:00:00
# Collecting aiohttp==3.8.2 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading aiohttp-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.5 MB/s eta 0:00:00
# Collecting PyYAML==6.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 41.1 MB/s eta 0:00:00
# Collecting deprecation==2.1.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.1.0)
# Collecting charset-normalizer<3.0,>=2.0 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting multidict<6.0,>=4.5 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (67.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (2023.7.22)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (41.0.4)
# Collecting aiodns>=1.1.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Downloading aiodns-3.1.1-py3-none-any.whl (5.4 kB)
# Collecting pyluach (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Collecting tzdata (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 9.7 MB/s eta 0:00:00
# Collecting korean-lunar-calendar (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.22)
# Collecting thriftpy2>=0.3.9 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading thriftpy2-0.4.17.tar.gz (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 kB 42.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pymysql>=0.7.6 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2023.3.post1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.11.3)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Collecting empyrical>=0.5.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.12.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.19.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Collecting tensorboardX>=1.9 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (9.0.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2023.6.0)
# Collecting aiohttp-cors (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 22.1 MB/s eta 0:00:00
# Collecting py-spy>=0.2.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 82.1 MB/s eta 0:00:00
# Collecting gpustat>=1.0.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 11.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting opencensus (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus-0.11.3-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.10.13)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.17.1)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.4.0)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.59.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.2.0)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.6.0)
# Collecting shimmy[atari]~=1.1.0 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting psycopg2-binary (from wrds<4,>=3->finrl==0.3.6)
#   Downloading psycopg2_binary-2.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 67.7 MB/s eta 0:00:00
# Collecting SQLAlchemy>=1.2.8 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.1 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.8)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.25.2)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6)
#   Downloading pycares-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 24.7 MB/s eta 0:00:00
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 39.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.3)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.10/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading nvidia_ml_py-12.535.108-py3-none-any.whl (36 kB)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 63.8 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.41.2)
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.27.7)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (17.0.2)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.11.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 31.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 64.3 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.10.6)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.61.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
# WARNING: The candidate selected for download or install is a yanked version: 'aiohttp' candidate (version 3.8.2 at https://files.pythonhosted.org/packages/8f/52/ea1e5eac3e748a94fdaafba5ab68adfb833f0cbdb68cc8149fbba5574176/aiohttp-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/aiohttp/) (requires-python:>=3.6))
# Reason for being yanked: This version includes overly restrictive multidict upper boundary disallowing multidict v6+. The previous patch version didn't have that and this is now causing dependency resolution problems for the users who have an "incompatible" version pinned. This is not really necessary anymore and will be addressed in the next release v3.8.3
#
# https://github.com/aio-libs/aiohttp/pull/6950
# Building wheels for collected packages: finrl, pyfolio, elegantrl, empyrical, gpustat, thriftpy2, box2d-py, AutoROM.accept-rom-license
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4669727 sha256=774d8e54a87cc0c59cbd23f022a5dceb9a6638cd6b33d462e607b3dbab1b5be1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nkk2s7rf/wheels/72/3b/1a/0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88649 sha256=e330c2efadd053dfd3f496e1f7677eabcc57ce25eaf18d5c3dec4733ed4c3dc5
#   Stored in directory: /root/.cache/pip/wheels/71/38/bc/e53700cfd8b0ad6b539d2fbaaf060ed8a299e7622a5b86ef42
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=197329 sha256=ff2989818e7f333dd2744d62e4319498d1504a82d809f7213f89653ecd27a5f4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nkk2s7rf/wheels/c0/51/a5/b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39755 sha256=143b62c036086f4bddc67959a48a864ad96a7ae6b6914f27f976f30fe964fa18
#   Stored in directory: /root/.cache/pip/wheels/0e/2e/f2/d6d2d9a1eb8fbbd9949bb5d4c00f753e3b74e5bd7ed10b1d36
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26534 sha256=9ad02cd420192b571261c52f70dc7b9608a9a50a369db846b50283d289a6f237
#   Stored in directory: /root/.cache/pip/wheels/ec/d7/80/a71ba3540900e1f276bcae685efd8e590c810d2108b95f1e47
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.17-cp310-cp310-linux_x86_64.whl size=1379583 sha256=06d5c5b5e599fef6a8b3d73e60dc02df535a5baae4f01ddd1399c664ad9f0cbb
#   Stored in directory: /root/.cache/pip/wheels/b3/ca/c1/bd8e4cd94145e4e79882fdf705ca021a7a7632248ce6d1d4f4
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373075 sha256=6dca30442afa9db1e5b905b35070617d90480e3df9a1170ea3e939c7e56956ad
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=291c7be76fbb1c887439b195c06ca135adf36bc8bbecdf2447990378afbb648d
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built finrl pyfolio elegantrl empyrical gpustat thriftpy2 box2d-py AutoROM.accept-rom-license
# Installing collected packages: py-spy, ply, opencensus-context, nvidia-ml-py, msgpack, korean-lunar-calendar, farama-notifications, distlib, colorful, box2d-py, websockets, virtualenv, urllib3, tzdata, thriftpy2, tensorboardX, SQLAlchemy, PyYAML, pymysql, pyluach, pygame, psycopg2-binary, multidict, jedi, gymnasium, deprecation, charset-normalizer, blessed, ale-py, shimmy, pycares, gpustat, wrds, stockstats, jqdatasdk, exchange-calendars, AutoROM.accept-rom-license, autorom, aiohttp, aiodns, ray, opencensus, empyrical, ccxt, alpaca-trade-api, aiohttp-cors, pyportfolioopt, pyfolio, stable-baselines3, elegantrl, finrl
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.7
#     Uninstalling msgpack-1.0.7:
#       Successfully uninstalled msgpack-1.0.7
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.6
#     Uninstalling urllib3-2.0.6:
#       Successfully uninstalled urllib3-2.0.6
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.22
#     Uninstalling SQLAlchemy-2.0.22:
#       Successfully uninstalled SQLAlchemy-2.0.22
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.4
#     Uninstalling multidict-6.0.4:
#       Successfully uninstalled multidict-6.0.4
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.0
#     Uninstalling charset-normalizer-3.3.0:
#       Successfully uninstalled charset-normalizer-3.3.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.6
#     Uninstalling aiohttp-3.8.6:
#       Successfully uninstalled aiohttp-3.8.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 PyYAML-6.0 SQLAlchemy-1.4.49 aiodns-3.1.1 aiohttp-3.8.2 aiohttp-cors-0.7.0 ale-py-0.8.1 alpaca-trade-api-3.0.2 autorom-0.6.1 blessed-1.20.0 box2d-py-2.3.5 ccxt-3.1.60 charset-normalizer-2.1.1 colorful-0.5.5 deprecation-2.1.0 distlib-0.3.7 elegantrl-0.3.6 empyrical-0.5.5 exchange-calendars-4.5 farama-notifications-0.0.4 finrl-0.3.6 gpustat-1.1.1 gymnasium-0.29.1 jedi-0.19.1 jqdatasdk-1.9.1 korean-lunar-calendar-0.3.1 msgpack-1.0.3 multidict-5.2.0 nvidia-ml-py-12.535.108 opencensus-0.11.3 opencensus-context-0.1.3 ply-3.11 psycopg2-binary-2.9.9 py-spy-0.3.14 pycares-4.4.0 pyfolio-0.9.2 pygame-2.1.0 pyluach-2.2.0 pymysql-1.1.0 pyportfolioopt-1.5.5 ray-2.7.1 shimmy-1.1.0 stable-baselines3-2.1.0 stockstats-0.5.4 tensorboardX-2.6.2.2 thriftpy2-0.4.17 tzdata-2023.3 urllib3-1.26.18 virtualenv-20.21.0 websockets-10.4 wrds-3.1.6

# %%
import os
import itertools
import sys

import pandas as pd
import numpy as np
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.config import INDICATORS
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl import config_tickers
from finrl.main import check_and_make_directories
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3
from finrl.config import INDICATORS

check_and_make_directories([TRAINED_MODEL_DIR])
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(

# %% [markdown]
# # Part 2. Fetch data

# %% [markdown]
# [yfinance](https://github.com/ranaroussi/yfinance) is an open-source library that provides APIs fetching historical data form Yahoo Finance. In FinRL, we have a class called [YahooDownloader](https://github.com/AI4Finance-Foundation/FinRL/blob/master/finrl/meta/preprocessor/yahoodownloader.py) that use yfinance to fetch data from Yahoo Finance.

# %% [markdown]
# **OHLCV**: Data downloaded are in the form of OHLCV, corresponding to **open, high, low, close, volume,** respectively. OHLCV is important because they contain most of numerical information of a stock in time series. From OHLCV, traders can get further judgement and prediction like the momentum, people's interest, market trends, etc.

# %% [markdown]
# ## Data for a single ticker

# %% [markdown]
# Here we provide two ways to fetch data with single ticker, let's take Apple Inc. (AAPL) as an example.

# %% [markdown]
# ## Data for the chosen tickers

# %%
config_tickers.DOW_30_TICKER
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'KO',
#  'JPM',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'CRM',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS',
#  'DOW']

# %%
len(config_tickers.DOW_30_TICKER)
# Out:
# 30

# %%
TRAIN_START_DATE = '2010-07-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2023-07-01'

# %%
df_dji = YahooDownloader(start_date = TRADE_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = ['^DJI']).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (755, 8)

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (95967, 8)

# %%
df_raw.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          date       open       high        low      close      volume   tic  \
# 0  2010-07-01   9.082143   9.100000   8.686429   7.532462  1022896000  AAPL
# 1  2010-07-01  52.590000  52.590000  51.000000  37.984497     9754700  AMGN
# 2  2010-07-01  39.549999  40.080002  38.419998  32.555141     8747200   AXP
# 3  2010-07-01  62.480000  62.720001  61.310001  49.130009     6465100    BA
# 4  2010-07-01  59.669998  60.700001  58.060001  42.267570    11598200   CAT
#
#    day
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3

# %% [markdown]
# # Part 3: Preprocess Data
# We check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %% [markdown]
# Hear let's take **MACD** as an example. Moving average convergence/divergence (MACD) is one of the most commonly used indicator showing bull and bear market. Its calculation is based on EMA (Exponential Moving Average indicator, measuring trend direction over a period of time.)

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Successfully added technical indicators
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (3271, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
processed_full.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          date   tic       open       high        low      close        volume  \
# 0  2010-07-01  AAPL   9.082143   9.100000   8.686429   7.532462  1.022896e+09
# 1  2010-07-01  AMGN  52.590000  52.590000  51.000000  37.984497  9.754700e+06
# 2  2010-07-01   AXP  39.549999  40.080002  38.419998  32.555141  8.747200e+06
# 3  2010-07-01    BA  62.480000  62.720001  61.310001  49.130009  6.465100e+06
# 4  2010-07-01   CAT  59.669998  60.700001  58.060001  42.267570  1.159820e+07
#
#    day  macd  boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  3.0   0.0  7.57514  7.443101     0.0 -66.666667  100.0      7.532462
# 1  3.0   0.0  7.57514  7.443101     0.0 -66.666667  100.0     37.984497
# 2  3.0   0.0  7.57514  7.443101     0.0 -66.666667  100.0     32.555141
# 3  3.0   0.0  7.57514  7.443101     0.0 -66.666667  100.0     49.130009
# 4  3.0   0.0  7.57514  7.443101     0.0 -66.666667  100.0     42.267570
#
#    close_60_sma        vix  turbulence
# 0      7.532462  32.860001         0.0
# 1     37.984497  32.860001         0.0
# 2     32.555141  32.860001         0.0
# 3     49.130009  32.860001         0.0
# 4     42.267570  32.860001         0.0

# %% [markdown]
# ### Split the data for training and trading

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 72993
# 21866
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Part 4. Environment

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# Training environment

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 5. Train DRL agents

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.0003,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

# set up logger
tmp_path = RESULTS_DIR + '/ppo'
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.0003, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 76         |
# |    iterations      | 1          |
# |    time_elapsed    | 26         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.86759174 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 2           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017346237 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0193     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.18        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0241     |
# |    reward               | -1.0480964  |
# |    std                  | 1           |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 3           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017981574 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00664    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.64        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | 0.98345846  |
# |    std                  | 1           |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 4           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.021286812 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.018      |
# |    reward               | 0.5728315   |
# |    std                  | 1           |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 5           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020291546 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00423    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0164     |
# |    reward               | 1.0749696   |
# |    std                  | 1.01        |
# |    value_loss           | 75.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 6           |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024292592 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0164     |
# |    reward               | -0.34486842 |
# |    std                  | 1.01        |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 7           |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023715608 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.029       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0265     |
# |    reward               | -1.2618     |
# |    std                  | 1.01        |
# |    value_loss           | 23.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 8           |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025943898 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.000166   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0203     |
# |    reward               | 1.164543    |
# |    std                  | 1.01        |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 9           |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.029568302 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.00654     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | -0.7912613  |
# |    std                  | 1.02        |
# |    value_loss           | 42.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 10         |
# |    time_elapsed         | 263        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02174871 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.7      |
# |    explained_variance   | 0.0234     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.8       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0195    |
# |    reward               | -3.2204359 |
# |    std                  | 1.02       |
# |    value_loss           | 46.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 11         |
# |    time_elapsed         | 289        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02034177 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.7      |
# |    explained_variance   | 0.00453    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.5       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0117    |
# |    reward               | 1.6426002  |
# |    std                  | 1.02       |
# |    value_loss           | 54.2       |
# ----------------------------------------
# day: 2516, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2508065.81
# total_reward: 1508065.81
# total_cost: 278898.70
# total_trades: 67405
# Sharpe: 0.650
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 12         |
# |    time_elapsed         | 314        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02496161 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.7      |
# |    explained_variance   | 0.0148     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.15       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0151    |
# |    reward               | -0.3893157 |
# |    std                  | 1.02       |
# |    value_loss           | 13.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 13          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021379119 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.0601     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0165     |
# |    reward               | 1.7351755   |
# |    std                  | 1.02        |
# |    value_loss           | 32.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 14          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024159363 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0129      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00964    |
# |    reward               | 0.3151678   |
# |    std                  | 1.03        |
# |    value_loss           | 64.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 15         |
# |    time_elapsed         | 392        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03605062 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.9      |
# |    explained_variance   | 0.000577   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12         |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0137    |
# |    reward               | 0.79562336 |
# |    std                  | 1.03       |
# |    value_loss           | 30.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 16          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.040713537 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.0374      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00919    |
# |    reward               | 0.10584364  |
# |    std                  | 1.03        |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 17          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.027544908 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00971    |
# |    reward               | 4.73227     |
# |    std                  | 1.03        |
# |    value_loss           | 57.2        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 78        |
# |    iterations           | 18        |
# |    time_elapsed         | 471       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0320577 |
# |    clip_fraction        | 0.286     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -42.2     |
# |    explained_variance   | 0.0357    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.62      |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.0163   |
# |    reward               | -1.643538 |
# |    std                  | 1.04      |
# |    value_loss           | 13.7      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 19          |
# |    time_elapsed         | 496         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026451282 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.1        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0159     |
# |    reward               | 2.1824038   |
# |    std                  | 1.04        |
# |    value_loss           | 48.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 20          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029449997 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.0302      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0112     |
# |    reward               | -0.17666128 |
# |    std                  | 1.05        |
# |    value_loss           | 81.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 21          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019312017 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.0148     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.5        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0127     |
# |    reward               | -0.53954786 |
# |    std                  | 1.05        |
# |    value_loss           | 56.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 22          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.029389258 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -0.023      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | -0.9090944  |
# |    std                  | 1.05        |
# |    value_loss           | 37.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 23          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.035380356 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -0.0312     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.32        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | 2.8789492   |
# |    std                  | 1.05        |
# |    value_loss           | 16.6        |
# -----------------------------------------
# day: 2516, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4004197.75
# total_reward: 3004197.75
# total_cost: 277780.47
# total_trades: 66659
# Sharpe: 0.846
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 24          |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.036111996 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.0412      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.58        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | 2.6541638   |
# |    std                  | 1.05        |
# |    value_loss           | 42.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 25          |
# |    time_elapsed         | 651         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.038345803 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.0368      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0154     |
# |    reward               | -0.07424594 |
# |    std                  | 1.06        |
# |    value_loss           | 70.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 26          |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022628022 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.0268      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00711    |
# |    reward               | 0.40700507  |
# |    std                  | 1.06        |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 27          |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.030769775 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.0375      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0094     |
# |    reward               | -8.67373    |
# |    std                  | 1.06        |
# |    value_loss           | 67.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 28         |
# |    time_elapsed         | 730        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01685574 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | 0.017      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.1       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0102    |
# |    reward               | -4.298937  |
# |    std                  | 1.06       |
# |    value_loss           | 78.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 29          |
# |    time_elapsed         | 755         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.020915164 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0.0343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0121     |
# |    reward               | -0.9996486  |
# |    std                  | 1.06        |
# |    value_loss           | 47.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 30          |
# |    time_elapsed         | 783         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014626791 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.0318      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | -1.2048056  |
# |    std                  | 1.06        |
# |    value_loss           | 71.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 78           |
# |    iterations           | 31           |
# |    time_elapsed         | 807          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.025367953  |
# |    clip_fraction        | 0.221        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.9        |
# |    explained_variance   | 0.0454       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0105      |
# |    reward               | -0.107291535 |
# |    std                  | 1.06         |
# |    value_loss           | 135          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 32         |
# |    time_elapsed         | 835        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02481545 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43        |
# |    explained_variance   | 0.0244     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.2       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0109    |
# |    reward               | -0.76375   |
# |    std                  | 1.07       |
# |    value_loss           | 62.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 33          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.020209689 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.0254      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0109     |
# |    reward               | 13.741152   |
# |    std                  | 1.07        |
# |    value_loss           | 163         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 34          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016292982 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.0811      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00627    |
# |    reward               | 2.7876353   |
# |    std                  | 1.07        |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 35          |
# |    time_elapsed         | 911         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.022375992 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | -0.0198     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00994    |
# |    reward               | -2.5974138  |
# |    std                  | 1.07        |
# |    value_loss           | 167         |
# -----------------------------------------
# day: 2516, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 5492011.27
# total_reward: 4492011.27
# total_cost: 241277.35
# total_trades: 63880
# Sharpe: 0.938
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 36         |
# |    time_elapsed         | 938        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02507969 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.1      |
# |    explained_variance   | 0.0187     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 173        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0116    |
# |    reward               | -0.9886763 |
# |    std                  | 1.07       |
# |    value_loss           | 263        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 37          |
# |    time_elapsed         | 963         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022852616 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.0642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 143         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00957    |
# |    reward               | 1.2192699   |
# |    std                  | 1.07        |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 38          |
# |    time_elapsed         | 990         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.031880137 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.00992     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00532    |
# |    reward               | 7.0820117   |
# |    std                  | 1.08        |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 39          |
# |    time_elapsed         | 1017        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.023012524 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | 0.0912      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00305    |
# |    reward               | 3.3683212   |
# |    std                  | 1.08        |
# |    value_loss           | 57.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 40          |
# |    time_elapsed         | 1043        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027615882 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | 0.0851      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.5        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00837    |
# |    reward               | -2.580379   |
# |    std                  | 1.08        |
# |    value_loss           | 106         |
# -----------------------------------------

# %% [markdown]
# # Part 6. Backtesting

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)

# %% [markdown]
# ### Backtest agents

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo,
    environment = e_trade_gym)
# Out:
# hit end!

# %% [markdown]
# # Part 7. Plotting

# %%
df_dji
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            date          open          high           low         close  \
# 0    2020-07-01  25879.380859  26019.310547  25713.609375  25734.970703
# 1    2020-07-02  25936.449219  26204.410156  25778.119141  25827.359375
# 2    2020-07-06  25996.080078  26297.529297  25996.080078  26287.029297
# 3    2020-07-07  26172.009766  26174.929688  25866.580078  25890.179688
# 4    2020-07-08  25950.060547  26109.490234  25816.250000  26067.279297
# ..          ...           ...           ...           ...           ...
# 750  2023-06-26  33730.789062  33819.488281  33610.320312  33714.710938
# 751  2023-06-27  33739.031250  33975.648438  33730.390625  33926.738281
# 752  2023-06-28  33881.378906  33903.761719  33755.921875  33852.660156
# 753  2023-06-29  33854.570312  34147.679688  33828.628906  34122.421875
# 754  2023-06-30  34269.921875  34467.351562  34269.921875  34407.601562
#
#         volume   tic  day
# 0    373180000  ^DJI    2
# 1    349130000  ^DJI    3
# 2    340690000  ^DJI    0
# 3    346820000  ^DJI    1
# 4    337300000  ^DJI    2
# ..         ...   ...  ...
# 750  265330000  ^DJI    0
# 751  293210000  ^DJI    1
# 752  268050000  ^DJI    2
# 753  279940000  ^DJI    3
# 754  351060000  ^DJI    4
#
# [755 rows x 8 columns]

# %%
df_dji = df_dji[['date','close']]
fst_day = df_dji['close'][0]
dji = pd.merge(df_dji['date'], df_dji['close'].div(fst_day).mul(1000000),
               how='outer', left_index=True, right_index=True).set_index('date')
dji.rename(columns = {'account_value':'DJIA'}, inplace = True)
# dji
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_ppo.rename(columns = {'account_value':'ppo'}, inplace = True)

result = pd.DataFrame()
result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True)
# result = pd.merge(result, MVO_result, how='outer', left_index=True, right_index=True)
result = pd.merge(result, dji, how='outer', left_index=True, right_index=True).fillna(method='bfill')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
col_name = ['PPO', 'DJIA']
result.columns = col_name
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Axes: xlabel='date'>
